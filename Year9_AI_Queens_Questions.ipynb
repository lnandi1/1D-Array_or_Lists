# %% [markdown]
# <a href="https://colab.research.google.com/github/lnandi1/1D-Array_or_Lists/blob/master/Year9_AI_Queens_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Analysis of G7 Countries**

# %% [markdown]
# ## **(1) Study the Program below and then write a Python Program which joins coordinates with straight lines with coordinates specified by you.**

# %%
# Program 1 - Plotting a straight line graph
import matplotlib.pyplot as plt
def Create_graph():
 x_numbers = [2, 3, 4]
 y_numbers = [2, 3, 4]
 
 plt.plot(x_numbers, y_numbers, marker='x')
 
 plt.xlabel('x_coordinate')
 plt.ylabel('y_coordinate')
 plt.title(" My First Plot")
 
 plt.show()
 
# Calling the Above Function
Create_graph()

# %% [markdown]
# ##**(2) Study the Program below which generates the Bar Chart shown and then write a Program which displays a Barchart of the Carbon Dioxide output in 2020 of these G7 countries. The Carbon Dioxide Output is given in Millions of Megatons**

# %% [markdown]
# <br>Canada &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;            559
# <br>Italy   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;            436
# <br>France  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;        377
# <br>UK     &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;     512
# <br>Germany   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;       833
# <br>Japan    &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;      1215
# <br>US     &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;     5676

# %%
# Insert Code

# %% [markdown]
# ## **(3) Study the Program below and write a Python Program which displays the relative percentage populations of the G7 Countries. Take the data from the program above.**

# %%
import matplotlib.pyplot as plt
# Pie chart
Cities = ['London','Paris','Berlin']
People_In_Millions = [8.9,2.1,3.6]
explode = (0.1,0.1,0.2)

fig1, ax1 = plt.subplots()
ax1.pie(People_In_Millions, explode= explode, labels=Cities, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  
plt.title("Population in Cities London, Paris, Berlin")

plt.show()
